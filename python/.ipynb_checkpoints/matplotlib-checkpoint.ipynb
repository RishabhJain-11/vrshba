# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Delhi = 3 cr
# Maharashtra = 13 cr
# Rajasthan = 8cr
# Uttar Pradesh = 24 cr
# Madhya Pradesh = 8.5 cr

x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.title("Our First Graph")
plt.xlabel("X Coordinates")
plt.ylabel("Y Coordinates")
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])

plt.show()
